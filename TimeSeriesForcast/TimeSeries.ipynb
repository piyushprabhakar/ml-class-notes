# %% [markdown]
# ![Screenshot 2024-09-28 at 10.38.13 AM.png](attachment:ae75e02d-b952-46ad-bcf7-4da2e4708a09.png)

# %% [markdown]
# ![Screenshot 2024-09-28 at 11.07.27 AM.png](attachment:fe28c566-6fc5-4d13-a197-ab0f37c03a3d.png)
# ![Screenshot 2024-09-28 at 10.53.04 AM.png](attachment:c70d579f-cb6e-49d3-b905-6874010b8481.png)
# ![Screenshot 2024-09-28 at 10.44.25 AM.png](attachment:23d578e7-fa41-4d3e-b62a-ffc32663b75d.png)

# %% [markdown]
# Decompisition is done to understand time series data
#
# Addition/Multiplication is used to see which works
